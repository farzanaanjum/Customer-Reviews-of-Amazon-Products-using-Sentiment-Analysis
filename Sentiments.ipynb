# %% [markdown]
#                                 Sentiments of Amazon Products

# %%
import seaborn as sns
from textblob import TextBlob
from matplotlib import pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\Microsoft\Desktop\DATA\data3.csv")
df.head()
# Out:
#                                         reviews.text
# 0  This product so far has not disappointed. My c...
# 1  great for beginner or experienced person. Boug...
# 2  Inexpensive tablet for him to use and learn on...
# 3  I've had my Fire HD 8 two weeks now and I love...
# 4  I bought this for my grand daughter when she c...

# %%
from textblob import TextBlob #processing textual data

bloblist_desc = list()

df_review_str=df['reviews.text'].astype(str)
for row in df_review_str:
    blob = TextBlob(row)
    bloblist_desc.append((row,blob.sentiment.polarity, blob.sentiment.subjectivity))
    df_polarity_desc = pd.DataFrame(bloblist_desc, columns = ['Review','sentiment','polarity'])
 
def f(df_polarity_desc):
    if df_polarity_desc['sentiment'] > 0:
        val = "Positive Review"
    elif df_polarity_desc['sentiment'] == 0:
        val = "Neutral Review"
    else:
        val = "Negative Review"
    return val

df_polarity_desc['Sentiments'] = df_polarity_desc.apply(f, axis=1)

plt.figure(figsize=(8, 8))

sns.set_style("whitegrid")

ax = sns.countplot(x="Sentiments", data=df_polarity_desc)

# %%
plt.show()

# %%
#df = pd.read_csv("C:\\Users\Microsoft\Documents\data3.csv")
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
matplotlib.style.use('ggplot')
plt.figure(figsize=(15,6))
N = 48
x1 = np.random.random(N)
y1= np.random.random(N)
#x1 = np.random.rand(N,M)
#y1 = np.random.rand(N,M)
X = np.arange(N)

plt.bar(X, x1, color ='r', hatch ='x', label="Negative")
plt.bar(X, x1+y1, bottom = x1, color ='c', hatch ='/', label="Positive")

plt.xlabel('Number of Products')
plt.ylabel('Number of Reviews')
plt.title('Amazon Products Sentiment')

plt.legend()

# %%
def percentageChange(StartPoint, CurrentPoint):
    return((fload(currentPoint)-StartPoint)/abs(StartPoint)) * 100.00
for eachN in sample:
    pc =percentageChange(sample[0], eachN)
    print(eachN, pc)

# %%
df = pd.read_csv("Percentage.csv")
df
# Out:
#                                                  name positive negative  \
# 0   All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...      80%      20%
# 1   All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...      20%      20%
# 2   All-New Kindle E-reader - Black, 6 Glare-Free ...      50%      50%
# 3   Amazon - Amazon Tap Portable Bluetooth and Wi-...      60%      40%
# 4   Amazon - Fire 16GB (5th Gen, 2015 Release) - B...      40%       1%
# 5   Amazon - Kindle Voyage - 4GB - Wi-Fi + 3G - Bl...      60%      10%
# 6   Amazon - Kindle Voyage - 4GB - Wi-Fi + 3G - Bl...      40%       1%
# 7   Amazon 5W USB Official OEM Charger and Power A...      60%      60%
# 8   Amazon 9W PowerFast Official OEM USB Charger a...       8%      10%
# 9   Amazon Echo and Fire TV Power Adapter,,,\r\r\n...      90%      40%
# 10  Amazon Fire Hd 10 Tablet, Wi-Fi, 16 Gb, Specia...      30%      20%
# 11  Amazon Fire Hd 6 Standing Protective Case(4th ...      60%      30%
# 12  Amazon Fire Hd 6 Standing Protective Case(4th ...      30%       5%
# 13  Amazon Fire Hd 8 8in Tablet 16gb Black B018szt...      30%      30%
# 14  Amazon Fire Kids Edition Tablet, 7 Display, Wi...      50%      30%
# 15           Amazon Fire Tv,,,\r\r\nAmazon Fire Tv,,,      70%      20%
# 16  Amazon Fire Tv,,,\r\r\nKindle Dx Leather Cover...      60%      30%
# 17  Amazon Kindle Fire 5ft USB to Micro-USB Cable ...      50%      40%
# 18  Amazon Kindle Fire Hd (3rd Generation) 8gb,,,\...      40%      30%
# 19  Amazon Kindle Lighted Leather Cover,,,\r\r\nAm...      40%      30%
# 20  Amazon Kindle Lighted Leather Cover,,,\r\r\nKi...      40%      30%
# 21  Amazon Kindle Paperwhite - eBook reader - 4 GB...      30%      30%
# 22  Amazon Kindle Touch Leather Case (4th Generati...      50%       2%
# 23  Amazon Standing Protective Case for Fire HD 6 ...      50%      50%
# 24  Brand New Amazon Kindle Fire 16gb 7 Ips Displa...      20%      10%
# 25  Certified Refurbished Amazon Fire TV (Previous...      50%      20%
# 26  Certified Refurbished Amazon Fire TV Stick (Pr...      40%      15%
# 27  Certified Refurbished Amazon Fire TV Stick (Pr...      50%      20%
# 28  Certified Refurbished Amazon Fire TV with Alex...      70%      30%
# 29  Coconut Water Red Tea 16.5 Oz (pack of 12),,,\...      20%      20%
# 30  Echo (Black),,,\r\r\nAmazon 9W PowerFast Offic...      50%      50%
# 31               Echo (Black),,,\r\r\nEcho (Black),,,      90%      30%
# 32               Echo (White),,,\r\r\nEcho (White),,,      40%       8%
# 33  Echo (White),,,\r\r\nFire Tablet, 7 Display, W...      80%      30%
# 34  Fire HD 8 Tablet with Alexa, 8 HD Display, 16 ...      50%      20%
# 35  Fire HD 8 Tablet with Alexa, 8 HD Display, 32 ...      60%      40%
# 36  Fire Kids Edition Tablet, 7 Display, Wi-Fi, 16...      71%      43%
# 37  Fire Tablet, 7 Display, Wi-Fi, 8 GB - Includes...      89%      50%
# 38  Fire Tablet, 7 Display, Wi-Fi, 8 GB - Includes...      41%      33%
# 39  Kindle Dx Leather Cover, Black (fits 9.7 Displ...      30%      29%
# 40         Kindle Keyboard,,,\r\r\nKindle Keyboard,,,      70%      51%
# 41  Kindle Oasis E-reader with Leather Charging Co...      62%      51%
# 42  Kindle Oasis E-reader with Leather Charging Co...      60%      15%
# 43  Kindle Paperwhite E-reader - White, 6 High-Res...      20%      10%
# 44     Kindle Paperwhite,,,\r\r\nKindle Paperwhite,,,      50%      41%
# 45  Kindle Voyage E-reader, 6 High-Resolution Disp...      40%      10%
# 46  Kindle Voyage E-reader, 6 High-Resolution Disp...      80%      51%
# 47  New Amazon Kindle Fire Hd 9w Powerfast Adapter...      90%      62%
#
#         Score
# 0   Excellect
# 1       Worst
# 2        Good
# 3        Good
# 4       Worst
# 5        Good
# 6       Worst
# 7        Good
# 8       Worst
# 9        Good
# 10      Worst
# 11       Good
# 12      Worst
# 13      Worst
# 14       Good
# 15       Good
# 16       Good
# 17       Good
# 18      Worst
# 19      Worst
# 20      Worst
# 21      Worst
# 22       Good
# 23       Good
# 24      Worst
# 25       Good
# 26       Good
# 27       Good
# 28       Good
# 29      Worst
# 30       Good
# 31  Excellect
# 32       Good
# 33  Excellect
# 34       Good
# 35       Good
# 36  Excellect
# 37  Excellect
# 38       Good
# 39      Worst
# 40       Good
# 41       Good
# 42       Good
# 43      Worst
# 44       Good
# 45       Good
# 46  Excellect
# 47  Excellect
